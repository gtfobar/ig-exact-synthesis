# %%
from z3 import Int, Bool, Ints, Bools, Solver, Or, Not, And, BV2Int, BitVec, BitVecs, BitVecVal, BitVec, Concat, Extract, IntVal, Implies
from typing import List

# %%
## Useful stuff from intel_altera
def vector_to_int(vector):
    result = 0
    for i, x in enumerate(vector):
        result += x * (2 ** i)
    return result


def int_to_vector(x, vector_dim):
    result = []
    for _ in range(vector_dim):
        result.append(x & 1)
        x >>= 1
    return result

# %%
## Important cell do not remove

def bool2int(x: bool) -> int:
    return x # 1 if x else 0


def bitvec2int(bitvec: List[bool]) -> int:
    result = 0
    for i, xi in enumerate(bitvec):
        xi = bool2int(xi)
        result += xi * (2 ** i)
    return result


def int2bitvec(i: int) -> List[bool]:
    result = []
    while i > 0:
        result.append(i & 1)
        i >>= 1
    return result


"""
f - битовый вектор длины 2 ** n
x - битовый вектор длины n
"""
def evaluate_fun(f: List[bool], x: List[bool]) -> bool:
    n = len(x)
    if (len(f) != 2 ** n):
        raise Exception("Bad arguments")
    x = bitvec2int(x)
    return f[x]

def z3_evaluate_fun(f, x):
    return f[BV2Int(x)]

# %%
def right_inclusive_range(start, end):
    return range(start + 1, end + 1)

def create_bitvec(name, bitlength):
    global_vars[name] = BitVec(name, bitlength)
    
def create_int(name):
    global_vars[name] = Int(name)
    
def add_assert(*asserts):
    for a in asserts:
        global_asserts.append(a)

# %%
cur_complexity = 1

global_vars = {}
global_asserts = []

# majority function
majority_bitvector = 0x15


# gate function
gate_bitvector = majority_bitvector
gate_arity = 3
gate_bitlength = 2 ** gate_arity   # 8

global_vars['gate'] = BitVec('gate', gate_bitlength)
global_vars['gate_value'] = BitVecVal(gate_bitvector, gate_bitlength)


# synthesized function
f_bitvector = 0x15
f_arity = 3
f_bitlength = 2 ** f_arity

global_vars['f'] = BitVec('f', f_bitlength)
global_vars['f_value'] = BitVecVal(f_bitvector, f_bitlength)

create_bitvec('output_polarity', 1)

for gate in right_inclusive_range(f_arity, f_arity + cur_complexity):
    for gate_input in range(gate_arity):
        create_bitvec(f'gate_input_polarity_{gate}_{gate_input}', 1)
        create_int(f'gate_input_number_{gate}_{gate_input}')

for f_input_value in range(f_bitlength):
    # bt0 = 0
    create_bitvec(f'gate_output_value_{f_input_value}_0', 1)
    
    # bti - f input values (xi, 1 <= i <= n - f inputs)
    for gate in right_inclusive_range(0, f_arity):
        create_bitvec(f'gate_output_value_{f_input_value}_{gate}', 1)
    
    for gate in right_inclusive_range(f_arity, f_arity + cur_complexity):
        # bti - gate output values (xi, n < i <= n + r - gates)
        create_bitvec(f'gate_output_value_{f_input_value}_{gate}', 1)
        
        # atic - gate input values
        for gate_input in range(gate_arity):
            create_bitvec(f'gate_input_value_{f_input_value}_{gate}_{gate_input}', 1)

# %%
global_vars
# Out:
# {'gate': gate,
#  'gate_value': 21,
#  'f': f,
#  'f_value': 64751,
#  'output_polarity': output_polarity,
#  'gate_input_polarity_6_0': gate_input_polarity_6_0,
#  'gate_input_number_6_0': gate_input_number_6_0,
#  'gate_input_polarity_6_1': gate_input_polarity_6_1,
#  'gate_input_number_6_1': gate_input_number_6_1,
#  'gate_input_polarity_6_2': gate_input_polarity_6_2,
#  'gate_input_number_6_2': gate_input_number_6_2,
#  'gate_output_value_0_0': gate_output_value_0_0,
#  'gate_output_value_0_1': gate_output_value_0_1,
#  'gate_output_value_0_2': gate_output_value_0_2,
#  'gate_output_value_0_3': gate_output_value_0_3,
#  'gate_output_value_0_4': gate_output_value_0_4,
#  'gate_output_value_0_5': gate_output_value_0_5,
#  'gate_output_value_0_6': gate_output_value_0_6,
#  'gate_input_value_0_6_0': gate_input_value_0_6_0,
#  'gate_input_value_0_6_1': gate_input_value_0_6_1,
#  'gate_input_value_0_6_2': gate_input_value_0_6_2,
#  'gate_output_value_0_7': gate_output_value_0_7,
#  'gate_input_value_0_7_0': gate_input_value_0_7_0,
#  'gate_input_value_0_7_1': gate_input_value_0_7_1,
#  'gate_input_value_0_7_2': gate_input_value_0_7_2,
#  'gate_output_value_0_8': gate_output_value_0_8,
#  'gate_input_value_0_8_0': gate_input_value_0_8_0,
#  'gate_input_value_0_8_1': gate_input_value_0_8_1,
#  'gate_input_value_0_8_2': gate_input_value_0_8_2,
#  'gate_output_value_0_9': gate_output_value_0_9,
#  'gate_input_value_0_9_0': gate_input_value_0_9_0,
#  'gate_input_value_0_9_1': gate_input_value_0_9_1,
#  'gate_input_value_0_9_2': gate_input_value_0_9_2,
#  'gate_output_value_0_10': gate_output_value_0_10,
#  'gate_input_value_0_10_0': gate_input_value_0_10_0,
#  'gate_input_value_0_10_1': gate_input_value_0_10_1,
#  'gate_input_value_0_10_2': gate_input_value_0_10_2,
#  'gate_output_value_1_0': gate_output_value_1_0,
#  'gate_output_value_1_1': gate_output_value_1_1,
#  'gate_output_value_1_2': gate_output_value_1_2,
#  'gate_output_value_1_3': gate_output_value_1_3,
#  'gate_output_value_1_4': gate_output_value_1_4,
#  'gate_output_value_1_5': gate_output_value_1_5,
#  'gate_output_value_1_6': gate_output_value_1_6,
#  'gate_input_value_1_6_0': gate_input_value_1_6_0,
#  'gate_input_value_1_6_1': gate_input_value_1_6_1,
#  'gate_input_value_1_6_2': gate_input_value_1_6_2,
#  'gate_output_value_1_7': gate_output_value_1_7,
#  'gate_input_value_1_7_0': gate_input_value_1_7_0,
#  'gate_input_value_1_7_1': gate_input_value_1_7_1,
#  'gate_input_value_1_7_2': gate_input_value_1_7_2,
#  'gate_output_value_1_8': gate_output_value_1_8,
#  'gate_input_value_1_8_0': gate_input_value_1_8_0,
#  'gate_input_value_1_8_1': gate_input_value_1_8_1,
#  'gate_input_value_1_8_2': gate_input_value_1_8_2,
#  'gate_output_value_1_9': gate_output_value_1_9,
#  'gate_input_value_1_9_0': gate_input_value_1_9_0,
#  'gate_input_value_1_9_1': gate_input_value_1_9_1,
#  'gate_input_value_1_9_2': gate_input_value_1_9_2,
#  'gate_output_value_1_10': gate_output_value_1_10,
#  'gate_input_value_1_10_0': gate_input_value_1_10_0,
#  'gate_input_value_1_10_1': gate_input_value_1_10_1,
#  'gate_input_value_1_10_2': gate_input_value_1_10_2,
#  'gate_output_value_2_0': gate_output_value_2_0,
#  'gate_output_value_2_1': gate_output_value_2_1,
#  'gate_output_value_2_2': gate_output_value_2_2,
#  'gate_output_value_2_3': gate_output_value_2_3,
#  'gate_output_value_2_4': gate_output_value_2_4,
#  'gate_output_value_2_5': gate_output_value_2_5,
#  'gate_output_value_2_6': gate_output_value_2_6,
#  'gate_input_value_2_6_0': gate_input_value_2_6_0,
#  'gate_input_value_2_6_1': gate_input_value_2_6_1,
#  'gate_input_value_2_6_2': gate_input_value_2_6_2,
#  'gate_output_value_2_7': gate_output_value_2_7,
#  'gate_input_value_2_7_0': gate_input_value_2_7_0,
#  'gate_input_value_2_7_1': gate_input_value_2_7_1,
#  'gate_input_value_2_7_2': gate_input_value_2_7_2,
#  'gate_output_value_2_8': gate_output_value_2_8,
#  'gate_input_value_2_8_0': gate_input_value_2_8_0,
#  'gate_input_value_2_8_1': gate_input_value_2_8_1,
#  'gate_input_value_2_8_2': gate_input_value_2_8_2,
#  'gate_output_value_2_9': gate_output_value_2_9,
#  'gate_input_value_2_9_0': gate_input_value_2_9_0,
#  'gate_input_value_2_9_1': gate_input_value_2_9_1,
#  'gate_input_value_2_9_2': gate_input_value_2_9_2,
#  'gate_output_value_2_10': gate_output_value_2_10,
#  'gate_input_value_2_10_0': gate_input_value_2_10_0,
#  'gate_input_value_2_10_1': gate_input_value_2_10_1,
#  'gate_input_value_2_10_2': gate_input_value_2_10_2,
#  'gate_output_value_3_0': gate_output_value_3_0,
#  'gate_output_value_3_1': gate_output_value_3_1,
#  'gate_output_value_3_2': gate_output_value_3_2,
#  'gate_output_value_3_3': gate_output_value_3_3,
#  'gate_output_value_3_4': gate_output_value_3_4,
#  'gate_output_value_3_5': gate_output_value_3_5,
#  'gate_output_value_3_6': gate_output_value_3_6,
#  'gate_input_value_3_6_0': gate_input_value_3_6_0,
#  'gate_input_value_3_6_1': gate_input_value_3_6_1,
#  'gate_input_value_3_6_2': gate_input_value_3_6_2,
#  'gate_output_value_3_7': gate_output_value_3_7,
#  'gate_input_value_3_7_0': gate_input_value_3_7_0,
#  'gate_input_value_3_7_1': gate_input_value_3_7_1,
#  'gate_input_value_3_7_2': gate_input_value_3_7_2,
#  'gate_output_value_3_8': gate_output_value_3_8,
#  'gate_input_value_3_8_0': gate_input_value_3_8_0,
#  'gate_input_value_3_8_1': gate_input_value_3_8_1,
#  'gate_input_value_3_8_2': gate_input_value_3_8_2,
#  'gate_output_value_3_9': gate_output_value_3_9,
#  'gate_input_value_3_9_0': gate_input_value_3_9_0,
#  'gate_input_value_3_9_1': gate_input_value_3_9_1,
#  'gate_input_value_3_9_2': gate_input_value_3_9_2,
#  'gate_output_value_3_10': gate_output_value_3_10,
#  'gate_input_value_3_10_0': gate_input_value_3_10_0,
#  'gate_input_value_3_10_1': gate_input_value_3_10_1,
#  'gate_input_value_3_10_2': gate_input_value_3_10_2,
#  'gate_output_value_4_0': gate_output_value_4_0,
#  'gate_output_value_4_1': gate_output_value_4_1,
#  'gate_output_value_4_2': gate_output_value_4_2,
#  'gate_output_value_4_3': gate_output_value_4_3,
#  'gate_output_value_4_4': gate_output_value_4_4,
#  'gate_output_value_4_5': gate_output_value_4_5,
#  'gate_output_value_4_6': gate_output_value_4_6,
#  'gate_input_value_4_6_0': gate_input_value_4_6_0,
#  'gate_input_value_4_6_1': gate_input_value_4_6_1,
#  'gate_input_value_4_6_2': gate_input_value_4_6_2,
#  'gate_output_value_4_7': gate_output_value_4_7,
#  'gate_input_value_4_7_0': gate_input_value_4_7_0,
#  'gate_input_value_4_7_1': gate_input_value_4_7_1,
#  'gate_input_value_4_7_2': gate_input_value_4_7_2,
#  'gate_output_value_4_8': gate_output_value_4_8,
#  'gate_input_value_4_8_0': gate_input_value_4_8_0,
#  'gate_input_value_4_8_1': gate_input_value_4_8_1,
#  'gate_input_value_4_8_2': gate_input_value_4_8_2,
#  'gate_output_value_4_9': gate_output_value_4_9,
#  'gate_input_value_4_9_0': gate_input_value_4_9_0,
#  'gate_input_value_4_9_1': gate_input_value_4_9_1,
#  'gate_input_value_4_9_2': gate_input_value_4_9_2,
#  'gate_output_value_4_10': gate_output_value_4_10,
#  'gate_input_value_4_10_0': gate_input_value_4_10_0,
#  'gate_input_value_4_10_1': gate_input_value_4_10_1,
#  'gate_input_value_4_10_2': gate_input_value_4_10_2,
#  'gate_output_value_5_0': gate_output_value_5_0,
#  'gate_output_value_5_1': gate_output_value_5_1,
#  'gate_output_value_5_2': gate_output_value_5_2,
#  'gate_output_value_5_3': gate_output_value_5_3,
#  'gate_output_value_5_4': gate_output_value_5_4,
#  'gate_output_value_5_5': gate_output_value_5_5,
#  'gate_output_value_5_6': gate_output_value_5_6,
#  'gate_input_value_5_6_0': gate_input_value_5_6_0,
#  'gate_input_value_5_6_1': gate_input_value_5_6_1,
#  'gate_input_value_5_6_2': gate_input_value_5_6_2,
#  'gate_output_value_5_7': gate_output_value_5_7,
#  'gate_input_value_5_7_0': gate_input_value_5_7_0,
#  'gate_input_value_5_7_1': gate_input_value_5_7_1,
#  'gate_input_value_5_7_2': gate_input_value_5_7_2,
#  'gate_output_value_5_8': gate_output_value_5_8,
#  'gate_input_value_5_8_0': gate_input_value_5_8_0,
#  'gate_input_value_5_8_1': gate_input_value_5_8_1,
#  'gate_input_value_5_8_2': gate_input_value_5_8_2,
#  'gate_output_value_5_9': gate_output_value_5_9,
#  'gate_input_value_5_9_0': gate_input_value_5_9_0,
#  'gate_input_value_5_9_1': gate_input_value_5_9_1,
#  'gate_input_value_5_9_2': gate_input_value_5_9_2,
#  'gate_output_value_5_10': gate_output_value_5_10,
#  'gate_input_value_5_10_0': gate_input_value_5_10_0,
#  'gate_input_value_5_10_1': gate_input_value_5_10_1,
#  'gate_input_value_5_10_2': gate_input_value_5_10_2,
#  'gate_output_value_6_0': gate_output_value_6_0,
#  'gate_output_value_6_1': gate_output_value_6_1,
#  'gate_output_value_6_2': gate_output_value_6_2,
#  'gate_output_value_6_3': gate_output_value_6_3,
#  'gate_output_value_6_4': gate_output_value_6_4,
#  'gate_output_value_6_5': gate_output_value_6_5,
#  'gate_output_value_6_6': gate_output_value_6_6,
#  'gate_input_value_6_6_0': gate_input_value_6_6_0,
#  'gate_input_value_6_6_1': gate_input_value_6_6_1,
#  'gate_input_value_6_6_2': gate_input_value_6_6_2,
#  'gate_output_value_6_7': gate_output_value_6_7,
#  'gate_input_value_6_7_0': gate_input_value_6_7_0,
#  'gate_input_value_6_7_1': gate_input_value_6_7_1,
#  'gate_input_value_6_7_2': gate_input_value_6_7_2,
#  'gate_output_value_6_8': gate_output_value_6_8,
#  'gate_input_value_6_8_0': gate_input_value_6_8_0,
#  'gate_input_value_6_8_1': gate_input_value_6_8_1,
#  'gate_input_value_6_8_2': gate_input_value_6_8_2,
#  'gate_output_value_6_9': gate_output_value_6_9,
#  'gate_input_value_6_9_0': gate_input_value_6_9_0,
#  'gate_input_value_6_9_1': gate_input_value_6_9_1,
#  'gate_input_value_6_9_2': gate_input_value_6_9_2,
#  'gate_output_value_6_10': gate_output_value_6_10,
#  'gate_input_value_6_10_0': gate_input_value_6_10_0,
#  'gate_input_value_6_10_1': gate_input_value_6_10_1,
#  'gate_input_value_6_10_2': gate_input_value_6_10_2,
#  'gate_output_value_7_0': gate_output_value_7_0,
#  'gate_output_value_7_1': gate_output_value_7_1,
#  'gate_output_value_7_2': gate_output_value_7_2,
#  'gate_output_value_7_3': gate_output_value_7_3,
#  'gate_output_value_7_4': gate_output_value_7_4,
#  'gate_output_value_7_5': gate_output_value_7_5,
#  'gate_output_value_7_6': gate_output_value_7_6,
#  'gate_input_value_7_6_0': gate_input_value_7_6_0,
#  'gate_input_value_7_6_1': gate_input_value_7_6_1,
#  'gate_input_value_7_6_2': gate_input_value_7_6_2,
#  'gate_output_value_7_7': gate_output_value_7_7,
#  'gate_input_value_7_7_0': gate_input_value_7_7_0,
#  'gate_input_value_7_7_1': gate_input_value_7_7_1,
#  'gate_input_value_7_7_2': gate_input_value_7_7_2,
#  'gate_output_value_7_8': gate_output_value_7_8,
#  'gate_input_value_7_8_0': gate_input_value_7_8_0,
#  'gate_input_value_7_8_1': gate_input_value_7_8_1,
#  'gate_input_value_7_8_2': gate_input_value_7_8_2,
#  'gate_output_value_7_9': gate_output_value_7_9,
#  'gate_input_value_7_9_0': gate_input_value_7_9_0,
#  'gate_input_value_7_9_1': gate_input_value_7_9_1,
#  'gate_input_value_7_9_2': gate_input_value_7_9_2,
#  'gate_output_value_7_10': gate_output_value_7_10,
#  'gate_input_value_7_10_0': gate_input_value_7_10_0,
#  'gate_input_value_7_10_1': gate_input_value_7_10_1,
#  'gate_input_value_7_10_2': gate_input_value_7_10_2,
#  'gate_output_value_8_0': gate_output_value_8_0,
#  'gate_output_value_8_1': gate_output_value_8_1,
#  'gate_output_value_8_2': gate_output_value_8_2,
#  'gate_output_value_8_3': gate_output_value_8_3,
#  'gate_output_value_8_4': gate_output_value_8_4,
#  'gate_output_value_8_5': gate_output_value_8_5,
#  'gate_output_value_8_6': gate_output_value_8_6,
#  'gate_input_value_8_6_0': gate_input_value_8_6_0,
#  'gate_input_value_8_6_1': gate_input_value_8_6_1,
#  'gate_input_value_8_6_2': gate_input_value_8_6_2,
#  'gate_output_value_8_7': gate_output_value_8_7,
#  'gate_input_value_8_7_0': gate_input_value_8_7_0,
#  'gate_input_value_8_7_1': gate_input_value_8_7_1,
#  'gate_input_value_8_7_2': gate_input_value_8_7_2,
#  'gate_output_value_8_8': gate_output_value_8_8,
#  'gate_input_value_8_8_0': gate_input_value_8_8_0,
#  'gate_input_value_8_8_1': gate_input_value_8_8_1,
#  'gate_input_value_8_8_2': gate_input_value_8_8_2,
#  'gate_output_value_8_9': gate_output_value_8_9,
#  'gate_input_value_8_9_0': gate_input_value_8_9_0,
#  'gate_input_value_8_9_1': gate_input_value_8_9_1,
#  'gate_input_value_8_9_2': gate_input_value_8_9_2,
#  'gate_output_value_8_10': gate_output_value_8_10,
#  'gate_input_value_8_10_0': gate_input_value_8_10_0,
#  'gate_input_value_8_10_1': gate_input_value_8_10_1,
#  'gate_input_value_8_10_2': gate_input_value_8_10_2,
#  'gate_output_value_9_0': gate_output_value_9_0,
#  'gate_output_value_9_1': gate_output_value_9_1,
#  'gate_output_value_9_2': gate_output_value_9_2,
#  'gate_output_value_9_3': gate_output_value_9_3,
#  'gate_output_value_9_4': gate_output_value_9_4,
#  'gate_output_value_9_5': gate_output_value_9_5,
#  'gate_output_value_9_6': gate_output_value_9_6,
#  'gate_input_value_9_6_0': gate_input_value_9_6_0,
#  'gate_input_value_9_6_1': gate_input_value_9_6_1,
#  'gate_input_value_9_6_2': gate_input_value_9_6_2,
#  'gate_output_value_9_7': gate_output_value_9_7,
#  'gate_input_value_9_7_0': gate_input_value_9_7_0,
#  'gate_input_value_9_7_1': gate_input_value_9_7_1,
#  'gate_input_value_9_7_2': gate_input_value_9_7_2,
#  'gate_output_value_9_8': gate_output_value_9_8,
#  'gate_input_value_9_8_0': gate_input_value_9_8_0,
#  'gate_input_value_9_8_1': gate_input_value_9_8_1,
#  'gate_input_value_9_8_2': gate_input_value_9_8_2,
#  'gate_output_value_9_9': gate_output_value_9_9,
#  'gate_input_value_9_9_0': gate_input_value_9_9_0,
#  'gate_input_value_9_9_1': gate_input_value_9_9_1,
#  'gate_input_value_9_9_2': gate_input_value_9_9_2,
#  'gate_output_value_9_10': gate_output_value_9_10,
#  'gate_input_value_9_10_0': gate_input_value_9_10_0,
#  'gate_input_value_9_10_1': gate_input_value_9_10_1,
#  'gate_input_value_9_10_2': gate_input_value_9_10_2,
#  'gate_output_value_10_0': gate_output_value_10_0,
#  'gate_output_value_10_1': gate_output_value_10_1,
#  'gate_output_value_10_2': gate_output_value_10_2,
#  'gate_output_value_10_3': gate_output_value_10_3,
#  'gate_output_value_10_4': gate_output_value_10_4,
#  'gate_output_value_10_5': gate_output_value_10_5,
#  'gate_output_value_10_6': gate_output_value_10_6,
#  'gate_input_value_10_6_0': gate_input_value_10_6_0,
#  'gate_input_value_10_6_1': gate_input_value_10_6_1,
#  'gate_input_value_10_6_2': gate_input_value_10_6_2,
#  'gate_output_value_10_7': gate_output_value_10_7,
#  'gate_input_value_10_7_0': gate_input_value_10_7_0,
#  'gate_input_value_10_7_1': gate_input_value_10_7_1,
#  'gate_input_value_10_7_2': gate_input_value_10_7_2,
#  'gate_output_value_10_8': gate_output_value_10_8,
#  'gate_input_value_10_8_0': gate_input_value_10_8_0,
#  'gate_input_value_10_8_1': gate_input_value_10_8_1,
#  'gate_input_value_10_8_2': gate_input_value_10_8_2,
#  'gate_output_value_10_9': gate_output_value_10_9,
#  'gate_input_value_10_9_0': gate_input_value_10_9_0,
#  'gate_input_value_10_9_1': gate_input_value_10_9_1,
#  'gate_input_value_10_9_2': gate_input_value_10_9_2,
#  'gate_output_value_10_10': gate_output_value_10_10,
#  'gate_input_value_10_10_0': gate_input_value_10_10_0,
#  'gate_input_value_10_10_1': gate_input_value_10_10_1,
#  'gate_input_value_10_10_2': gate_input_value_10_10_2,
#  'gate_output_value_11_0': gate_output_value_11_0,
#  'gate_output_value_11_1': gate_output_value_11_1,
#  'gate_output_value_11_2': gate_output_value_11_2,
#  'gate_output_value_11_3': gate_output_value_11_3,
#  'gate_output_value_11_4': gate_output_value_11_4,
#  'gate_output_value_11_5': gate_output_value_11_5,
#  'gate_output_value_11_6': gate_output_value_11_6,
#  'gate_input_value_11_6_0': gate_input_value_11_6_0,
#  'gate_input_value_11_6_1': gate_input_value_11_6_1,
#  'gate_input_value_11_6_2': gate_input_value_11_6_2,
#  'gate_output_value_11_7': gate_output_value_11_7,
#  'gate_input_value_11_7_0': gate_input_value_11_7_0,
#  'gate_input_value_11_7_1': gate_input_value_11_7_1,
#  'gate_input_value_11_7_2': gate_input_value_11_7_2,
#  'gate_output_value_11_8': gate_output_value_11_8,
#  'gate_input_value_11_8_0': gate_input_value_11_8_0,
#  'gate_input_value_11_8_1': gate_input_value_11_8_1,
#  'gate_input_value_11_8_2': gate_input_value_11_8_2,
#  'gate_output_value_11_9': gate_output_value_11_9,
#  'gate_input_value_11_9_0': gate_input_value_11_9_0,
#  'gate_input_value_11_9_1': gate_input_value_11_9_1,
#  'gate_input_value_11_9_2': gate_input_value_11_9_2,
#  'gate_output_value_11_10': gate_output_value_11_10,
#  'gate_input_value_11_10_0': gate_input_value_11_10_0,
#  'gate_input_value_11_10_1': gate_input_value_11_10_1,
#  'gate_input_value_11_10_2': gate_input_value_11_10_2,
#  'gate_output_value_12_0': gate_output_value_12_0,
#  'gate_output_value_12_1': gate_output_value_12_1,
#  'gate_output_value_12_2': gate_output_value_12_2,
#  'gate_output_value_12_3': gate_output_value_12_3,
#  'gate_output_value_12_4': gate_output_value_12_4,
#  'gate_output_value_12_5': gate_output_value_12_5,
#  'gate_output_value_12_6': gate_output_value_12_6,
#  'gate_input_value_12_6_0': gate_input_value_12_6_0,
#  'gate_input_value_12_6_1': gate_input_value_12_6_1,
#  'gate_input_value_12_6_2': gate_input_value_12_6_2,
#  'gate_output_value_12_7': gate_output_value_12_7,
#  'gate_input_value_12_7_0': gate_input_value_12_7_0,
#  'gate_input_value_12_7_1': gate_input_value_12_7_1,
#  'gate_input_value_12_7_2': gate_input_value_12_7_2,
#  'gate_output_value_12_8': gate_output_value_12_8,
#  'gate_input_value_12_8_0': gate_input_value_12_8_0,
#  'gate_input_value_12_8_1': gate_input_value_12_8_1,
#  'gate_input_value_12_8_2': gate_input_value_12_8_2,
#  'gate_output_value_12_9': gate_output_value_12_9,
#  'gate_input_value_12_9_0': gate_input_value_12_9_0,
#  'gate_input_value_12_9_1': gate_input_value_12_9_1,
#  'gate_input_value_12_9_2': gate_input_value_12_9_2,
#  'gate_output_value_12_10': gate_output_value_12_10,
#  'gate_input_value_12_10_0': gate_input_value_12_10_0,
#  'gate_input_value_12_10_1': gate_input_value_12_10_1,
#  'gate_input_value_12_10_2': gate_input_value_12_10_2,
#  'gate_output_value_13_0': gate_output_value_13_0,
#  'gate_output_value_13_1': gate_output_value_13_1,
#  'gate_output_value_13_2': gate_output_value_13_2,
#  'gate_output_value_13_3': gate_output_value_13_3,
#  'gate_output_value_13_4': gate_output_value_13_4,
#  'gate_output_value_13_5': gate_output_value_13_5,
#  'gate_output_value_13_6': gate_output_value_13_6,
#  'gate_input_value_13_6_0': gate_input_value_13_6_0,
#  'gate_input_value_13_6_1': gate_input_value_13_6_1,
#  'gate_input_value_13_6_2': gate_input_value_13_6_2,
#  'gate_output_value_13_7': gate_output_value_13_7,
#  'gate_input_value_13_7_0': gate_input_value_13_7_0,
#  'gate_input_value_13_7_1': gate_input_value_13_7_1,
#  'gate_input_value_13_7_2': gate_input_value_13_7_2,
#  'gate_output_value_13_8': gate_output_value_13_8,
#  'gate_input_value_13_8_0': gate_input_value_13_8_0,
#  'gate_input_value_13_8_1': gate_input_value_13_8_1,
#  'gate_input_value_13_8_2': gate_input_value_13_8_2,
#  'gate_output_value_13_9': gate_output_value_13_9,
#  'gate_input_value_13_9_0': gate_input_value_13_9_0,
#  'gate_input_value_13_9_1': gate_input_value_13_9_1,
#  'gate_input_value_13_9_2': gate_input_value_13_9_2,
#  'gate_output_value_13_10': gate_output_value_13_10,
#  'gate_input_value_13_10_0': gate_input_value_13_10_0,
#  'gate_input_value_13_10_1': gate_input_value_13_10_1,
#  'gate_input_value_13_10_2': gate_input_value_13_10_2,
#  'gate_output_value_14_0': gate_output_value_14_0,
#  'gate_output_value_14_1': gate_output_value_14_1,
#  'gate_output_value_14_2': gate_output_value_14_2,
#  'gate_output_value_14_3': gate_output_value_14_3,
#  'gate_output_value_14_4': gate_output_value_14_4,
#  'gate_output_value_14_5': gate_output_value_14_5,
#  'gate_output_value_14_6': gate_output_value_14_6,
#  'gate_input_value_14_6_0': gate_input_value_14_6_0,
#  'gate_input_value_14_6_1': gate_input_value_14_6_1,
#  'gate_input_value_14_6_2': gate_input_value_14_6_2,
#  'gate_output_value_14_7': gate_output_value_14_7,
#  'gate_input_value_14_7_0': gate_input_value_14_7_0,
#  'gate_input_value_14_7_1': gate_input_value_14_7_1,
#  'gate_input_value_14_7_2': gate_input_value_14_7_2,
#  'gate_output_value_14_8': gate_output_value_14_8,
#  'gate_input_value_14_8_0': gate_input_value_14_8_0,
#  'gate_input_value_14_8_1': gate_input_value_14_8_1,
#  'gate_input_value_14_8_2': gate_input_value_14_8_2,
#  'gate_output_value_14_9': gate_output_value_14_9,
#  'gate_input_value_14_9_0': gate_input_value_14_9_0,
#  'gate_input_value_14_9_1': gate_input_value_14_9_1,
#  'gate_input_value_14_9_2': gate_input_value_14_9_2,
#  'gate_output_value_14_10': gate_output_value_14_10,
#  'gate_input_value_14_10_0': gate_input_value_14_10_0,
#  'gate_input_value_14_10_1': gate_input_value_14_10_1,
#  'gate_input_value_14_10_2': gate_input_value_14_10_2,
#  'gate_output_value_15_0': gate_output_value_15_0,
#  'gate_output_value_15_1': gate_output_value_15_1,
#  'gate_output_value_15_2': gate_output_value_15_2,
#  'gate_output_value_15_3': gate_output_value_15_3,
#  'gate_output_value_15_4': gate_output_value_15_4,
#  'gate_output_value_15_5': gate_output_value_15_5,
#  'gate_output_value_15_6': gate_output_value_15_6,
#  'gate_input_value_15_6_0': gate_input_value_15_6_0,
#  'gate_input_value_15_6_1': gate_input_value_15_6_1,
#  'gate_input_value_15_6_2': gate_input_value_15_6_2,
#  'gate_output_value_15_7': gate_output_value_15_7,
#  'gate_input_value_15_7_0': gate_input_value_15_7_0,
#  'gate_input_value_15_7_1': gate_input_value_15_7_1,
#  'gate_input_value_15_7_2': gate_input_value_15_7_2,
#  'gate_output_value_15_8': gate_output_value_15_8,
#  'gate_input_value_15_8_0': gate_input_value_15_8_0,
#  'gate_input_value_15_8_1': gate_input_value_15_8_1,
#  'gate_input_value_15_8_2': gate_input_value_15_8_2,
#  'gate_output_value_15_9': gate_output_value_15_9,
#  'gate_input_value_15_9_0': gate_input_value_15_9_0,
#  'gate_input_value_15_9_1': gate_input_value_15_9_1,
#  'gate_input_value_15_9_2': gate_input_value_15_9_2,
#  'gate_output_value_15_10': gate_output_value_15_10,
#  'gate_input_value_15_10_0': gate_input_value_15_10_0,
#  'gate_input_value_15_10_1': gate_input_value_15_10_1,
#  'gate_input_value_15_10_2': gate_input_value_15_10_2}

# %%
for gate in right_inclusive_range(f_arity, f_arity + complexity):
    for gate_input in range(gate_input_width):        
        s = global_vars[f'gate_input_number_{gate}_{gate_input}']
        
        # нет циклов
        add_assert(s <= gate)

        # номера операндов неотрицательны
        add_assert(s >= 0)
   

    # TODO: generalize
    # номера операндов упорядоченны
    s1 = global_vars[f'gate_input_number_{gate}_0']
    s2 = global_vars[f'gate_input_number_{gate}_1']
    s3 = global_vars[f'gate_input_number_{gate}_2']
    
    add_assert(s1 < s2, s2 < s3)
    
    
    # TODO: generalize
    # (Оптимиз.) не более одного операнда инвертировано
    p1 = global_vars[f'gate_input_polarity_{gate}_0']
    p2 = global_vars[f'gate_input_polarity_{gate}_1']
    p3 = global_vars[f'gate_input_polarity_{gate}_2']
    
    add_assert(((p1 | p2) & (p2 | p3) & (p1 | p3)) == 1)
    

for f_input_value in range(f_bitlength):
    bt0 = global_vars[f'gate_output_value_{f_input_value}_0']
    add_assert(bt0 == 0)
    
    bt_out = global_vars[f'gate_output_value_{f_input_value}_{f_arity + cur_complexity}']
    p_out = global_vars['output_polarity']
    f = global_vars['f']
    i = f_input_value
    
    add_assert(bt_out == ~p_out + Extract(i, i, f))
    
    for gate in right_inclusive_range(f_arity, f_arity + cur_complexity):
        # TODO: generalize
        a1 = global_vars[f'gate_input_value_{f_input_value}_{gate}_0']
        a2 = global_vars[f'gate_input_value_{f_input_value}_{gate}_1']
        a3 = global_vars[f'gate_input_value_{f_input_value}_{gate}_2']
        
        b = global_vars[f'gate_output_value_{f_input_value}_{gate}']
        add_assert(b == ((a1 | a2) & (a1 | a3) & (a2 | a3)))

        for gate_input in range(gate_input_width):
            a = global_vars[f'gate_input_value_{f_input_value}_{gate}_{gate_input}']
            p = global_vars[f'gate_input_polarity_{gate}_{gate_input}']
            s = global_vars[f'gate_input_number_{gate}_{gate_input}']
            
            for j in range(f_arity):
                b = global_vars[f'gate_output_value_{f_input_value}_{j}']
                add_assert(Implies(s == j, a == b + ~p))

# %%
global_asserts
# Out:
# [gate_input_number_6_0 <= 6,
#  gate_input_number_6_0 >= 0,
#  gate_input_number_6_1 <= 6,
#  gate_input_number_6_1 >= 0,
#  gate_input_number_6_2 <= 6,
#  gate_input_number_6_2 >= 0,
#  gate_input_number_6_0 < gate_input_number_6_1,
#  gate_input_number_6_1 < gate_input_number_6_2,
#  (gate_input_polarity_6_0 | gate_input_polarity_6_1) &
#  (gate_input_polarity_6_1 | gate_input_polarity_6_2) &
#  (gate_input_polarity_6_0 | gate_input_polarity_6_2) ==
#  1,
#  gate_output_value_0_0 == 0,
#  gate_output_value_0_6 == ~output_polarity + Extract(0, 0, f),
#  gate_output_value_15_4 ==
#  (gate_input_value_0_6_0 | gate_input_value_0_6_1) &
#  (gate_input_value_0_6_0 | gate_input_value_0_6_2) &
#  (gate_input_value_0_6_1 | gate_input_value_0_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_0_6_0 ==
#          gate_output_value_0_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_0_6_0 ==
#          gate_output_value_0_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_0_6_0 ==
#          gate_output_value_0_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_0_6_0 ==
#          gate_output_value_0_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_0_6_0 ==
#          gate_output_value_0_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_0_6_1 ==
#          gate_output_value_0_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_0_6_1 ==
#          gate_output_value_0_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_0_6_1 ==
#          gate_output_value_0_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_0_6_1 ==
#          gate_output_value_0_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_0_6_1 ==
#          gate_output_value_0_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_0_6_2 ==
#          gate_output_value_0_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_0_6_2 ==
#          gate_output_value_0_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_0_6_2 ==
#          gate_output_value_0_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_0_6_2 ==
#          gate_output_value_0_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_0_6_2 ==
#          gate_output_value_0_4 + ~gate_input_polarity_6_2),
#  gate_output_value_1_0 == 0,
#  gate_output_value_1_6 == ~output_polarity + Extract(1, 1, f),
#  gate_output_value_0_4 ==
#  (gate_input_value_1_6_0 | gate_input_value_1_6_1) &
#  (gate_input_value_1_6_0 | gate_input_value_1_6_2) &
#  (gate_input_value_1_6_1 | gate_input_value_1_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_1_6_0 ==
#          gate_output_value_1_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_1_6_0 ==
#          gate_output_value_1_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_1_6_0 ==
#          gate_output_value_1_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_1_6_0 ==
#          gate_output_value_1_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_1_6_0 ==
#          gate_output_value_1_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_1_6_1 ==
#          gate_output_value_1_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_1_6_1 ==
#          gate_output_value_1_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_1_6_1 ==
#          gate_output_value_1_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_1_6_1 ==
#          gate_output_value_1_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_1_6_1 ==
#          gate_output_value_1_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_1_6_2 ==
#          gate_output_value_1_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_1_6_2 ==
#          gate_output_value_1_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_1_6_2 ==
#          gate_output_value_1_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_1_6_2 ==
#          gate_output_value_1_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_1_6_2 ==
#          gate_output_value_1_4 + ~gate_input_polarity_6_2),
#  gate_output_value_2_0 == 0,
#  gate_output_value_2_6 == ~output_polarity + Extract(2, 2, f),
#  gate_output_value_1_4 ==
#  (gate_input_value_2_6_0 | gate_input_value_2_6_1) &
#  (gate_input_value_2_6_0 | gate_input_value_2_6_2) &
#  (gate_input_value_2_6_1 | gate_input_value_2_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_2_6_0 ==
#          gate_output_value_2_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_2_6_0 ==
#          gate_output_value_2_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_2_6_0 ==
#          gate_output_value_2_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_2_6_0 ==
#          gate_output_value_2_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_2_6_0 ==
#          gate_output_value_2_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_2_6_1 ==
#          gate_output_value_2_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_2_6_1 ==
#          gate_output_value_2_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_2_6_1 ==
#          gate_output_value_2_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_2_6_1 ==
#          gate_output_value_2_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_2_6_1 ==
#          gate_output_value_2_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_2_6_2 ==
#          gate_output_value_2_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_2_6_2 ==
#          gate_output_value_2_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_2_6_2 ==
#          gate_output_value_2_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_2_6_2 ==
#          gate_output_value_2_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_2_6_2 ==
#          gate_output_value_2_4 + ~gate_input_polarity_6_2),
#  gate_output_value_3_0 == 0,
#  gate_output_value_3_6 == ~output_polarity + Extract(3, 3, f),
#  gate_output_value_2_4 ==
#  (gate_input_value_3_6_0 | gate_input_value_3_6_1) &
#  (gate_input_value_3_6_0 | gate_input_value_3_6_2) &
#  (gate_input_value_3_6_1 | gate_input_value_3_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_3_6_0 ==
#          gate_output_value_3_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_3_6_0 ==
#          gate_output_value_3_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_3_6_0 ==
#          gate_output_value_3_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_3_6_0 ==
#          gate_output_value_3_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_3_6_0 ==
#          gate_output_value_3_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_3_6_1 ==
#          gate_output_value_3_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_3_6_1 ==
#          gate_output_value_3_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_3_6_1 ==
#          gate_output_value_3_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_3_6_1 ==
#          gate_output_value_3_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_3_6_1 ==
#          gate_output_value_3_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_3_6_2 ==
#          gate_output_value_3_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_3_6_2 ==
#          gate_output_value_3_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_3_6_2 ==
#          gate_output_value_3_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_3_6_2 ==
#          gate_output_value_3_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_3_6_2 ==
#          gate_output_value_3_4 + ~gate_input_polarity_6_2),
#  gate_output_value_4_0 == 0,
#  gate_output_value_4_6 == ~output_polarity + Extract(4, 4, f),
#  gate_output_value_3_4 ==
#  (gate_input_value_4_6_0 | gate_input_value_4_6_1) &
#  (gate_input_value_4_6_0 | gate_input_value_4_6_2) &
#  (gate_input_value_4_6_1 | gate_input_value_4_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_4_6_0 ==
#          gate_output_value_4_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_4_6_0 ==
#          gate_output_value_4_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_4_6_0 ==
#          gate_output_value_4_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_4_6_0 ==
#          gate_output_value_4_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_4_6_0 ==
#          gate_output_value_4_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_4_6_1 ==
#          gate_output_value_4_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_4_6_1 ==
#          gate_output_value_4_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_4_6_1 ==
#          gate_output_value_4_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_4_6_1 ==
#          gate_output_value_4_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_4_6_1 ==
#          gate_output_value_4_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_4_6_2 ==
#          gate_output_value_4_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_4_6_2 ==
#          gate_output_value_4_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_4_6_2 ==
#          gate_output_value_4_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_4_6_2 ==
#          gate_output_value_4_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_4_6_2 ==
#          gate_output_value_4_4 + ~gate_input_polarity_6_2),
#  gate_output_value_5_0 == 0,
#  gate_output_value_5_6 == ~output_polarity + Extract(5, 5, f),
#  gate_output_value_4_4 ==
#  (gate_input_value_5_6_0 | gate_input_value_5_6_1) &
#  (gate_input_value_5_6_0 | gate_input_value_5_6_2) &
#  (gate_input_value_5_6_1 | gate_input_value_5_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_5_6_0 ==
#          gate_output_value_5_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_5_6_0 ==
#          gate_output_value_5_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_5_6_0 ==
#          gate_output_value_5_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_5_6_0 ==
#          gate_output_value_5_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_5_6_0 ==
#          gate_output_value_5_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_5_6_1 ==
#          gate_output_value_5_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_5_6_1 ==
#          gate_output_value_5_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_5_6_1 ==
#          gate_output_value_5_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_5_6_1 ==
#          gate_output_value_5_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_5_6_1 ==
#          gate_output_value_5_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_5_6_2 ==
#          gate_output_value_5_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_5_6_2 ==
#          gate_output_value_5_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_5_6_2 ==
#          gate_output_value_5_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_5_6_2 ==
#          gate_output_value_5_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_5_6_2 ==
#          gate_output_value_5_4 + ~gate_input_polarity_6_2),
#  gate_output_value_6_0 == 0,
#  gate_output_value_6_6 == ~output_polarity + Extract(6, 6, f),
#  gate_output_value_5_4 ==
#  (gate_input_value_6_6_0 | gate_input_value_6_6_1) &
#  (gate_input_value_6_6_0 | gate_input_value_6_6_2) &
#  (gate_input_value_6_6_1 | gate_input_value_6_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_6_6_0 ==
#          gate_output_value_6_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_6_6_0 ==
#          gate_output_value_6_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_6_6_0 ==
#          gate_output_value_6_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_6_6_0 ==
#          gate_output_value_6_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_6_6_0 ==
#          gate_output_value_6_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_6_6_1 ==
#          gate_output_value_6_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_6_6_1 ==
#          gate_output_value_6_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_6_6_1 ==
#          gate_output_value_6_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_6_6_1 ==
#          gate_output_value_6_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_6_6_1 ==
#          gate_output_value_6_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_6_6_2 ==
#          gate_output_value_6_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_6_6_2 ==
#          gate_output_value_6_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_6_6_2 ==
#          gate_output_value_6_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_6_6_2 ==
#          gate_output_value_6_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_6_6_2 ==
#          gate_output_value_6_4 + ~gate_input_polarity_6_2),
#  gate_output_value_7_0 == 0,
#  gate_output_value_7_6 == ~output_polarity + Extract(7, 7, f),
#  gate_output_value_6_4 ==
#  (gate_input_value_7_6_0 | gate_input_value_7_6_1) &
#  (gate_input_value_7_6_0 | gate_input_value_7_6_2) &
#  (gate_input_value_7_6_1 | gate_input_value_7_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_7_6_0 ==
#          gate_output_value_7_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_7_6_0 ==
#          gate_output_value_7_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_7_6_0 ==
#          gate_output_value_7_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_7_6_0 ==
#          gate_output_value_7_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_7_6_0 ==
#          gate_output_value_7_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_7_6_1 ==
#          gate_output_value_7_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_7_6_1 ==
#          gate_output_value_7_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_7_6_1 ==
#          gate_output_value_7_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_7_6_1 ==
#          gate_output_value_7_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_7_6_1 ==
#          gate_output_value_7_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_7_6_2 ==
#          gate_output_value_7_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_7_6_2 ==
#          gate_output_value_7_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_7_6_2 ==
#          gate_output_value_7_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_7_6_2 ==
#          gate_output_value_7_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_7_6_2 ==
#          gate_output_value_7_4 + ~gate_input_polarity_6_2),
#  gate_output_value_8_0 == 0,
#  gate_output_value_8_6 == ~output_polarity + Extract(8, 8, f),
#  gate_output_value_7_4 ==
#  (gate_input_value_8_6_0 | gate_input_value_8_6_1) &
#  (gate_input_value_8_6_0 | gate_input_value_8_6_2) &
#  (gate_input_value_8_6_1 | gate_input_value_8_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_8_6_0 ==
#          gate_output_value_8_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_8_6_0 ==
#          gate_output_value_8_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_8_6_0 ==
#          gate_output_value_8_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_8_6_0 ==
#          gate_output_value_8_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_8_6_0 ==
#          gate_output_value_8_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_8_6_1 ==
#          gate_output_value_8_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_8_6_1 ==
#          gate_output_value_8_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_8_6_1 ==
#          gate_output_value_8_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_8_6_1 ==
#          gate_output_value_8_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_8_6_1 ==
#          gate_output_value_8_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_8_6_2 ==
#          gate_output_value_8_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_8_6_2 ==
#          gate_output_value_8_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_8_6_2 ==
#          gate_output_value_8_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_8_6_2 ==
#          gate_output_value_8_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_8_6_2 ==
#          gate_output_value_8_4 + ~gate_input_polarity_6_2),
#  gate_output_value_9_0 == 0,
#  gate_output_value_9_6 == ~output_polarity + Extract(9, 9, f),
#  gate_output_value_8_4 ==
#  (gate_input_value_9_6_0 | gate_input_value_9_6_1) &
#  (gate_input_value_9_6_0 | gate_input_value_9_6_2) &
#  (gate_input_value_9_6_1 | gate_input_value_9_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_9_6_0 ==
#          gate_output_value_9_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_9_6_0 ==
#          gate_output_value_9_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_9_6_0 ==
#          gate_output_value_9_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_9_6_0 ==
#          gate_output_value_9_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_9_6_0 ==
#          gate_output_value_9_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_9_6_1 ==
#          gate_output_value_9_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_9_6_1 ==
#          gate_output_value_9_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_9_6_1 ==
#          gate_output_value_9_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_9_6_1 ==
#          gate_output_value_9_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_9_6_1 ==
#          gate_output_value_9_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_9_6_2 ==
#          gate_output_value_9_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_9_6_2 ==
#          gate_output_value_9_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_9_6_2 ==
#          gate_output_value_9_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_9_6_2 ==
#          gate_output_value_9_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_9_6_2 ==
#          gate_output_value_9_4 + ~gate_input_polarity_6_2),
#  gate_output_value_10_0 == 0,
#  gate_output_value_10_6 ==
#  ~output_polarity + Extract(10, 10, f),
#  gate_output_value_9_4 ==
#  (gate_input_value_10_6_0 | gate_input_value_10_6_1) &
#  (gate_input_value_10_6_0 | gate_input_value_10_6_2) &
#  (gate_input_value_10_6_1 | gate_input_value_10_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_10_6_0 ==
#          gate_output_value_10_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_10_6_0 ==
#          gate_output_value_10_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_10_6_0 ==
#          gate_output_value_10_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_10_6_0 ==
#          gate_output_value_10_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_10_6_0 ==
#          gate_output_value_10_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_10_6_1 ==
#          gate_output_value_10_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_10_6_1 ==
#          gate_output_value_10_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_10_6_1 ==
#          gate_output_value_10_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_10_6_1 ==
#          gate_output_value_10_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_10_6_1 ==
#          gate_output_value_10_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_10_6_2 ==
#          gate_output_value_10_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_10_6_2 ==
#          gate_output_value_10_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_10_6_2 ==
#          gate_output_value_10_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_10_6_2 ==
#          gate_output_value_10_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_10_6_2 ==
#          gate_output_value_10_4 + ~gate_input_polarity_6_2),
#  gate_output_value_11_0 == 0,
#  gate_output_value_11_6 ==
#  ~output_polarity + Extract(11, 11, f),
#  gate_output_value_10_4 ==
#  (gate_input_value_11_6_0 | gate_input_value_11_6_1) &
#  (gate_input_value_11_6_0 | gate_input_value_11_6_2) &
#  (gate_input_value_11_6_1 | gate_input_value_11_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_11_6_0 ==
#          gate_output_value_11_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_11_6_0 ==
#          gate_output_value_11_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_11_6_0 ==
#          gate_output_value_11_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_11_6_0 ==
#          gate_output_value_11_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_11_6_0 ==
#          gate_output_value_11_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_11_6_1 ==
#          gate_output_value_11_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_11_6_1 ==
#          gate_output_value_11_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_11_6_1 ==
#          gate_output_value_11_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_11_6_1 ==
#          gate_output_value_11_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_11_6_1 ==
#          gate_output_value_11_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_11_6_2 ==
#          gate_output_value_11_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_11_6_2 ==
#          gate_output_value_11_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_11_6_2 ==
#          gate_output_value_11_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_11_6_2 ==
#          gate_output_value_11_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_11_6_2 ==
#          gate_output_value_11_4 + ~gate_input_polarity_6_2),
#  gate_output_value_12_0 == 0,
#  gate_output_value_12_6 ==
#  ~output_polarity + Extract(12, 12, f),
#  gate_output_value_11_4 ==
#  (gate_input_value_12_6_0 | gate_input_value_12_6_1) &
#  (gate_input_value_12_6_0 | gate_input_value_12_6_2) &
#  (gate_input_value_12_6_1 | gate_input_value_12_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_12_6_0 ==
#          gate_output_value_12_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_12_6_0 ==
#          gate_output_value_12_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_12_6_0 ==
#          gate_output_value_12_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_12_6_0 ==
#          gate_output_value_12_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_12_6_0 ==
#          gate_output_value_12_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_12_6_1 ==
#          gate_output_value_12_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_12_6_1 ==
#          gate_output_value_12_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_12_6_1 ==
#          gate_output_value_12_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_12_6_1 ==
#          gate_output_value_12_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_12_6_1 ==
#          gate_output_value_12_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_12_6_2 ==
#          gate_output_value_12_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_12_6_2 ==
#          gate_output_value_12_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_12_6_2 ==
#          gate_output_value_12_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_12_6_2 ==
#          gate_output_value_12_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_12_6_2 ==
#          gate_output_value_12_4 + ~gate_input_polarity_6_2),
#  gate_output_value_13_0 == 0,
#  gate_output_value_13_6 ==
#  ~output_polarity + Extract(13, 13, f),
#  gate_output_value_12_4 ==
#  (gate_input_value_13_6_0 | gate_input_value_13_6_1) &
#  (gate_input_value_13_6_0 | gate_input_value_13_6_2) &
#  (gate_input_value_13_6_1 | gate_input_value_13_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_13_6_0 ==
#          gate_output_value_13_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_13_6_0 ==
#          gate_output_value_13_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_13_6_0 ==
#          gate_output_value_13_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_13_6_0 ==
#          gate_output_value_13_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_13_6_0 ==
#          gate_output_value_13_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_13_6_1 ==
#          gate_output_value_13_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_13_6_1 ==
#          gate_output_value_13_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_13_6_1 ==
#          gate_output_value_13_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_13_6_1 ==
#          gate_output_value_13_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_13_6_1 ==
#          gate_output_value_13_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_13_6_2 ==
#          gate_output_value_13_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_13_6_2 ==
#          gate_output_value_13_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_13_6_2 ==
#          gate_output_value_13_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_13_6_2 ==
#          gate_output_value_13_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_13_6_2 ==
#          gate_output_value_13_4 + ~gate_input_polarity_6_2),
#  gate_output_value_14_0 == 0,
#  gate_output_value_14_6 ==
#  ~output_polarity + Extract(14, 14, f),
#  gate_output_value_13_4 ==
#  (gate_input_value_14_6_0 | gate_input_value_14_6_1) &
#  (gate_input_value_14_6_0 | gate_input_value_14_6_2) &
#  (gate_input_value_14_6_1 | gate_input_value_14_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_14_6_0 ==
#          gate_output_value_14_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_14_6_0 ==
#          gate_output_value_14_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_14_6_0 ==
#          gate_output_value_14_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_14_6_0 ==
#          gate_output_value_14_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_14_6_0 ==
#          gate_output_value_14_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_14_6_1 ==
#          gate_output_value_14_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_14_6_1 ==
#          gate_output_value_14_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_14_6_1 ==
#          gate_output_value_14_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_14_6_1 ==
#          gate_output_value_14_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_14_6_1 ==
#          gate_output_value_14_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_14_6_2 ==
#          gate_output_value_14_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_14_6_2 ==
#          gate_output_value_14_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_14_6_2 ==
#          gate_output_value_14_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_14_6_2 ==
#          gate_output_value_14_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_14_6_2 ==
#          gate_output_value_14_4 + ~gate_input_polarity_6_2),
#  gate_output_value_15_0 == 0,
#  gate_output_value_15_6 ==
#  ~output_polarity + Extract(15, 15, f),
#  gate_output_value_14_4 ==
#  (gate_input_value_15_6_0 | gate_input_value_15_6_1) &
#  (gate_input_value_15_6_0 | gate_input_value_15_6_2) &
#  (gate_input_value_15_6_1 | gate_input_value_15_6_2),
#  Implies(gate_input_number_6_0 == 0,
#          gate_input_value_15_6_0 ==
#          gate_output_value_15_0 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 1,
#          gate_input_value_15_6_0 ==
#          gate_output_value_15_1 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 2,
#          gate_input_value_15_6_0 ==
#          gate_output_value_15_2 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 3,
#          gate_input_value_15_6_0 ==
#          gate_output_value_15_3 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_0 == 4,
#          gate_input_value_15_6_0 ==
#          gate_output_value_15_4 + ~gate_input_polarity_6_0),
#  Implies(gate_input_number_6_1 == 0,
#          gate_input_value_15_6_1 ==
#          gate_output_value_15_0 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 1,
#          gate_input_value_15_6_1 ==
#          gate_output_value_15_1 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 2,
#          gate_input_value_15_6_1 ==
#          gate_output_value_15_2 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 3,
#          gate_input_value_15_6_1 ==
#          gate_output_value_15_3 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_1 == 4,
#          gate_input_value_15_6_1 ==
#          gate_output_value_15_4 + ~gate_input_polarity_6_1),
#  Implies(gate_input_number_6_2 == 0,
#          gate_input_value_15_6_2 ==
#          gate_output_value_15_0 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 1,
#          gate_input_value_15_6_2 ==
#          gate_output_value_15_1 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 2,
#          gate_input_value_15_6_2 ==
#          gate_output_value_15_2 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 3,
#          gate_input_value_15_6_2 ==
#          gate_output_value_15_3 + ~gate_input_polarity_6_2),
#  Implies(gate_input_number_6_2 == 4,
#          gate_input_value_15_6_2 ==
#          gate_output_value_15_4 + ~gate_input_polarity_6_2)]

# %%
s = Solver()
s.add([i for i in global_asserts])
s.check()
# Out:
# sat

# %%
res = list(s.model())
res.sort(key=lambda x : x.name())

# %%
res[0].value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 res[0].value
#
# AttributeError: 'FuncDeclRef' object has no attribute 'value'

# %%
solver = Solver()
s1.add(maj == BitVecVal(bitvec2int(MAJ), 8))


for i in right_inclusive_range(n, n + max_complexity):
    for
    
    ss = Ints(f's0{i} s1{i} s2{i}')
    ps = BitVecs(f'p0{i} p1{i} p2{i}', 1)
    
    numbers.append(ss)
    polarities.append(ps)
    
    for c in range(3):
        # нет циклов
        solver.add(ss[c] <= i)
        
        # номера операндов неотрицательны
        solver.add(ss[c] >= 0)
        
    # (Оптимиз.) не более одного операнда инвертировано
    solver.add(Or(ps[0], ps[1]), Or(ps[1], ps[2]), Or(ps[0], ps[2])
               
     # номера операндов упорядоченны
    solver.add(ss[0] < ss[1], ss[1] < ss[2])
    
    bs = []
    a_ss = []
    for t in range(2 ** n):
        b = BitVecs(f'b{t}_{i}', 1)
        a_s = BitVecs(f'a{t}_1{i} a{t}_2{i} a{t}_3{i}', 1)
        
        bs.append(b)
        a_ss.append(a_s)
        
        t_bitvec = int2bitvec(t)
        
        # функционирование элемента голосования
        
        solver.add((a_s[0] or a_s[1]) and (a_s[1] or a_s[2]) and (a_s[0] or a_s[2]))



solver.check()
solver.model()
# Out:
#   Input In [35]
#     solver.add(ss[0] < ss[1], ss[1] < ss[2])
#     ^
# SyntaxError: invalid syntax

# %%
solve(s)

# %%
basis = {MAJ}

# %%
evaluate_fun([1,0,0,0], [1,1])
bitvec2int([1,0,1,1])

# %%
int2bitvec(8)

# %%
evaluate_fun([0, 0, 0, 1], [1, 1])
# Out:
# 1

# %%
# Out:
# 2

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 Function
#
# NameError: name 'Function' is not defined

# %%
# Out:
# False

# %%
x, y, z, r = Bools('x y z r')
s1 = Solver()

MAJ = [0, 0, 0, 1, 0, 1, 1, 1]
x = BitVec('x', 3)

# %%
s1.check()
# Out:
# sat

# %%
s1.model()
# Out:
# [f = 232]

# %%
int2bitvec(232)
# Out:
# [0, 0, 0, 1, 0, 1, 1, 1]

# %%
v1 = BitVec('v1', 1)
v2 = BitVec('v2', 1)
v3 = BitVec('v3', 1)

f = BitVecVal(9, 8)

# %%
s1 = Solver()
s1.add(~v1 == 1)
s1.check()
s1.model()
# Out:
# [v1 = 0]

# %% [markdown]
# v4

# %%
v4
# Out:
# BV2Int(Concat(Concat(v1, v2), v3))

# %%
a = 8
a.bit_length()
# Out:
# 4
